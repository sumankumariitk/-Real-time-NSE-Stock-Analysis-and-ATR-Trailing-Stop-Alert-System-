# %%
import yfinance as yf
import pandas as pd
import time
from datetime import datetime

# %%
# Function to calculate Average True Range (ATR)
def calculate_atr(data, period):
    high_low_diff = data['High'] - data['Low']
    high_close_diff = abs(data['High'] - data['Close'].shift(1))
    low_close_diff = abs(data['Low'] - data['Close'].shift(1))
    true_range = pd.DataFrame({'HL': high_low_diff, 'HC': high_close_diff, 'LC': low_close_diff}).max(axis=1)
    atr = true_range.rolling(period).mean()
    return atr

# %%
# Function to generate buy and sell alerts based on ATR and price conditions
def generate_alerts(stock_symbols, atr_period, key_value):
    while True:
        try:
            for stock_symbol in stock_symbols:
                data = yf.download(stock_symbol, period="1d", interval="1m")
                atr = calculate_atr(data, atr_period)

                trailing_stop = 0
                position = 0

                for i in range(len(data)):
                    close_price = data['Close'][i]
                    atr_value = atr[i]

                    if position == 1 and close_price < trailing_stop:
                        alert_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                        print(f"Sell alert for {stock_symbol} at {alert_time}!")
                        position = 0
                    elif position == -1 and close_price > trailing_stop:
                        alert_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                        print(f"Buy alert for {stock_symbol} at {alert_time}!")
                        position = 0

                    if close_price > trailing_stop:
                        trailing_stop = max(trailing_stop, close_price - key_value * atr_value)
                        position = 1
                    elif close_price < trailing_stop:
                        trailing_stop = min(trailing_stop, close_price + key_value * atr_value)
                        position = -1
                        
            time.sleep(60)  # Sleep for 1 minute before fetching new data
        except Exception as e:
            print("Error:", e)
            time.sleep(60)  # Sleep in case of an error

# %%
if __name__ == '__main__':
    stock_symbols = ['IRFC.NS']  # Replace with the desired stock symbols
    atr_period = 10  # Replace with the desired ATR period
    key_value = 1  # Replace with the desired key value
    
    generate_alerts(stock_symbols, atr_period, key_value)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# Sell alert for IRFC.NS at 2023-08-25 15:31:11!
# Buy alert for IRFC.NS at 2023-08-25 15:31:11!
# [*********************100%***********************]  1 of 1 completed
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# Sell alert for IRFC.NS at 2023-08-25 15:32:12!
# Buy alert for IRFC.NS at 2023-08-25 15:32:12!
# [*********************100%***********************]  1 of 1 completed
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# Sell alert for IRFC.NS at 2023-08-25 15:33:14!
# Buy alert for IRFC.NS at 2023-08-25 15:33:14!
# [*********************100%***********************]  1 of 1 completed
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# Sell alert for IRFC.NS at 2023-08-25 15:34:15!
# Buy alert for IRFC.NS at 2023-08-25 15:34:15!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 atr_period = 10  # Replace with the desired ATR period
#       4 key_value = 1  # Replace with the desired key value
# ----> 6 generate_alerts(stock_symbols, atr_period, key_value)
#
# Cell In[4], line 6, in generate_alerts(stock_symbols, atr_period, key_value)
#       4 try:
#       5     for stock_symbol in stock_symbols:
# ----> 6         data = yf.download(stock_symbol, period="1d", interval="1m")
#       7         atr = calculate_atr(data, atr_period)
#       9         trailing_stop = 0
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\yfinance\utils.py:107, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     104 logger.debug(f'Entering {func.__name__}()')
#     106 with IndentationContext():
# --> 107     result = func(*args, **kwargs)
#     109 logger.debug(f'Exiting {func.__name__}()')
#     110 return result
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\yfinance\multi.py:157, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, session)
#     150         _download_one_threaded(ticker, period=period, interval=interval,
#     151                                start=start, end=end, prepost=prepost,
#     152                                actions=actions, auto_adjust=auto_adjust,
#     153                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     154                                progress=(progress and i > 0), proxy=proxy,
#     155                                rounding=rounding, timeout=timeout, session=session)
#     156     while len(shared._DFS) < len(tickers):
# --> 157         _time.sleep(0.01)
#     158 # download synchronously
#     159 else:
#     160     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:
